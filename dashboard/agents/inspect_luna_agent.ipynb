# %%
from pathlib import Path
path = Path(r'C:/Users/Administrator/Documents/NEXO DIGITAL/01_ATIVOS/NEXO_DASHBOARD_PRO/agents/luna-cto-agent.cjs')
print(path.exists())
text = path.read_text(encoding='utf-16', errors='replace')
lines = text.splitlines()
for i, line in enumerate(lines[:120], start=1):
    print(f'{i}: {line}')
